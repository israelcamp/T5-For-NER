# %%
import os
from argparse import Namespace

# %%
import pytorch_lightning as pl

# %%
from src.models.modeling_conll2003 import T5ForConll2003

# %%
hparams = {"experiment_name": "Overfit T5 on CoNLL2003",
           "batch_size": 1, "num_workers": 2,
           "optimizer": "Adam", "lr": 5e-3,
           "datapath": "../data/conll2003",
           "source_max_length": 128,
           "target_max_length": 256,
           "labels_mode": 'tokens',
           "shuffle_train": False,
           "pretrained_model": 't5-small'
           }
hparams = Namespace(**hparams)

# %%
model = T5ForConll2003.from_pretrained(hparams.pretrained_model, hparams=hparams)

# %%
examples = model.get_examples()

# %%
examples.keys()
# Out:
# dict_keys(['train', 'valid', 'test'])

# %%
all_examples = sum(list(examples.values()), [])

# %%
len(all_examples)
# Out:
# 22134

# %%
ex = all_examples[0]

# %%
lens = [len(model.tokenizer.tokenize(ex.target)) for ex in all_examples]

# %%
lens = [len(model.tokenizer.tokenize(ex.source)) for ex in all_examples]

# %%
sorted(lens, reverse=True)
# Out:
# [212,
#  202,
#  198,
#  195,
#  178,
#  174,
#  172,
#  167,
#  155,
#  151,
#  142,
#  141,
#  127,
#  126,
#  126,
#  125,
#  121,
#  111,
#  110,
#  109,
#  104,
#  103,
#  95,
#  95,
#  94,
#  92,
#  92,
#  92,
#  91,
#  90,
#  89,
#  88,
#  88,
#  87,
#  87,
#  87,
#  87,
#  86,
#  86,
#  86,
#  85,
#  84,
#  84,
#  84,
#  83,
#  82,
#  82,
#  81,
#  80,
#  80,
#  80,
#  80,
#  80,
#  80,
#  80,
#  79,
#  79,
#  79,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  78,
#  77,
#  77,
#  77,
#  77,
#  77,
#  77,
#  77,
#  76,
#  76,
#  76,
#  75,
#  75,
#  75,
#  75,
#  75,
#  75,
#  75,
#  75,
#  75,
#  75,
#  75,
#  74,
#  74,
#  74,
#  74,
#  74,
#  74,
#  74,
#  74,
#  74,
#  73,
#  73,
#  73,
#  73,
#  73,
#  73,
#  73,
#  73,
#  73,
#  73,
#  73,
#  73,
#  72,
#  72,
#  72,
#  72,
#  72,
#  72,
#  72,
#  72,
#  72,
#  72,
#  72,
#  72,
#  72,
#  71,
#  71,
#  71,
#  71,
#  71,
#  71,
#  71,
#  71,
#  71,
#  70,
#  70,
#  70,
#  70,
#  70,
#  70,
#  70,
#  70,
#  70,
# ...
